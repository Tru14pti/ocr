# %%
import cv2
from matplotlib import pyplot as plt

import glob
images = [cv2.imread(file) for file in glob.glob("C:/Users/shantanu/Passion_IT/Images/*.jpeg")]

# %%
def display(im_path):
    dpi = 80
    im_data = plt.imread(im_path)

    height, width  = im_data.shape[:2]
    
    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

# %%
import ipyplot

ipyplot.plot_images(images)
# Out:
# C:\Users\shantanu\anaconda3\lib\site-packages\ipyplot\_utils.py:97: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.asarray(seq)
#     <style>
#         #ipyplot-html-viewer-toggle-MqP6AsTCFf4gQH8cVFmExA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MqP6AsTCFf4gQH8cVFmExA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MqP6AsTCFf4gQH8cVFmExA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MqP6AsTCFf4gQH8cVFmExA:checked ~ #ipyplot-html-viewer-textarea-MqP6AsTCFf4gQH8cVFmExA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MqP6AsTCFf4gQH8cVFmExA:checked + #ipyplot-html-viewer-label-MqP6AsTCFf4gQH8cVFmExA:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-MqP6AsTCFf4gQH8cVFmExA">
#         <label id="ipyplot-html-viewer-label-MqP6AsTCFf4gQH8cVFmExA" for="ipyplot-html-viewer-toggle-MqP6AsTCFf4gQH8cVFmExA">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-MqP6AsTCFf4gQH8cVFmExA" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-WYpfvPcA7g62u7uTzs63TW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WYpfvPcA7g62u7uTzs63TW {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WYpfvPcA7g62u7uTzs63TW">
#     <div class="ipyplot-placeholder-div-WYpfvPcA7g62u7uTzs63TW">
#         <div id="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-7SRaxXCSkhr8BMj2yQh52R" class="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-7SRaxXCSkhr8BMj2yQh52R">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYpfvPcA7g62u7uTzs63TW">
#         <div id="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-DLyBpbBKJ4SmpcYyoLvCDc" class="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-DLyBpbBKJ4SmpcYyoLvCDc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYpfvPcA7g62u7uTzs63TW">
#         <div id="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-KvfBBHTNYjQ74kGcoWAtzT" class="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-KvfBBHTNYjQ74kGcoWAtzT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYpfvPcA7g62u7uTzs63TW">
#         <div id="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-4X96RzFHDC6Gb8TUv9424Z" class="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-4X96RzFHDC6Gb8TUv9424Z">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-WYpfvPcA7g62u7uTzs63TW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WYpfvPcA7g62u7uTzs63TW {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WYpfvPcA7g62u7uTzs63TW">
#     <div class="ipyplot-placeholder-div-WYpfvPcA7g62u7uTzs63TW">
#         <div id="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-7SRaxXCSkhr8BMj2yQh52R" class="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-7SRaxXCSkhr8BMj2yQh52R">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYpfvPcA7g62u7uTzs63TW">
#         <div id="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-DLyBpbBKJ4SmpcYyoLvCDc" class="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-DLyBpbBKJ4SmpcYyoLvCDc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYpfvPcA7g62u7uTzs63TW">
#         <div id="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-KvfBBHTNYjQ74kGcoWAtzT" class="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-KvfBBHTNYjQ74kGcoWAtzT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYpfvPcA7g62u7uTzs63TW">
#         <div id="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-4X96RzFHDC6Gb8TUv9424Z" class="ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYpfvPcA7g62u7uTzs63TW-4X96RzFHDC6Gb8TUv9424Z">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
pip ins
